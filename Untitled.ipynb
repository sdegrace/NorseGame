# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
skills = pd.read_excel('./skills.xlsx', index_col=0)
alignments = pd.read_excel('./alignments.xlsx', index_col=0)

# %%
skills.describe()
# Out:
#             tactics          lore    perception  investigation     deduction  \
# count  10001.000000  10001.000000  10001.000000   10001.000000  10001.000000
# mean     213.909889    181.373623    178.543426     204.543566    202.138386
# std      201.904428    152.024667    134.564923     186.611645    173.907199
# min        0.000000      0.000000      0.000000       0.000000      0.000000
# 25%       66.000000     69.000000     79.000000      72.000000     72.000000
# 50%      151.000000    142.000000    148.200000     148.000000    157.200000
# 75%      294.600000    248.400000    240.000000     279.400000    281.000000
# max     1920.000000   1331.200000    992.000000    1836.800000   1410.000000
#
#               power     athletics       healing  intimidation   performance  \
# count  10001.000000  10001.000000  10001.000000  10001.000000  10001.000000
# mean     213.226197    177.263194    193.005499    187.508429    191.227917
# ...

# %%
alignments.describe()
# Out:
#               odin          thor          loki
# count  10001.00000  10001.000000  10001.000000
# mean      16.60354     16.160884     15.680332
# std        8.70876      8.856535      8.858572
# min        0.00000      0.000000      0.000000
# 25%       10.00000      9.000000      9.000000
# 50%       16.00000     16.000000     15.000000
# 75%       23.00000     22.000000     22.000000
# max       60.00000     53.000000     53.000000

# %%
skills.describe()
# Out:
#             tactics          lore    perception  investigation     deduction  \
# count  10001.000000  10001.000000  10001.000000   10001.000000  10001.000000
# mean     213.909889    181.373623    178.543426     204.543566    202.138386
# std      201.904428    152.024667    134.564923     186.611645    173.907199
# min        0.000000      0.000000      0.000000       0.000000      0.000000
# 25%       66.000000     69.000000     79.000000      72.000000     72.000000
# 50%      151.000000    142.000000    148.200000     148.000000    157.200000
# 75%      294.600000    248.400000    240.000000     279.400000    281.000000
# max     1920.000000   1331.200000    992.000000    1836.800000   1410.000000
#
#               power     athletics       healing  intimidation   performance  \
# count  10001.000000  10001.000000  10001.000000  10001.000000  10001.000000
# mean     213.226197    177.263194    193.005499    187.508429    191.227917
# ...

# %%
skills.describe().loc['50%'].median()
# Out:
# 148.2

# %%
skills.plot.kde(figsize=(20,5))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
skills.hist(bins=100, figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'tactics'}>,
#         <AxesSubplot:title={'center':'lore'}>,
#         <AxesSubplot:title={'center':'perception'}>,
#         <AxesSubplot:title={'center':'investigation'}>],
#        [<AxesSubplot:title={'center':'deduction'}>,
#         <AxesSubplot:title={'center':'power'}>,
#         <AxesSubplot:title={'center':'athletics'}>,
#         <AxesSubplot:title={'center':'healing'}>],
#        [<AxesSubplot:title={'center':'intimidation'}>,
#         <AxesSubplot:title={'center':'performance'}>,
#         <AxesSubplot:title={'center':'accuracy'}>,
#         <AxesSubplot:title={'center':'speed'}>],
#        [<AxesSubplot:title={'center':'persuasion'}>,
#         <AxesSubplot:title={'center':'deception'}>,
#         <AxesSubplot:title={'center':'stealth'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
skills.max(axis=1).hist(bins=100, figsize=(20,5))
# Out:
# <AxesSubplot:>

# %%
print(skills.max(axis=1).median())
skills.max(axis=1).plot.kde(figsize=(20,5))
# Out:
# 511.6
# <AxesSubplot:ylabel='Density'>

# %%
print(skills.min(axis=1).median())
skills.min(axis=1).hist(bins=50, figsize=(20,5))
# Out:
# 28.0
# <AxesSubplot:>

# %%
print(skills.min(axis=1).median())
skills.min(axis=1).plot.kde(figsize=(20,5))
# Out:
# 28.0
# <AxesSubplot:ylabel='Density'>

# %%
alignments.plot.kde(figsize=(20,5))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
alignments.max(axis=1).describe()
# Out:
# count    10001.000000
# mean        25.541646
# std          6.242282
# min          0.000000
# 25%         21.000000
# 50%         25.000000
# 75%         29.000000
# max         60.000000
# dtype: float64
